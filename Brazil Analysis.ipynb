# %%
# %load_ext sql
# %sql mysql+pymysql://root:12345678@localhost:3306/brazil
# Out:
# 'Connected: root@brazil'

# %% [markdown]
# ## Table of Contents
#
# 1. [Customer Analysis](#customer)
# 2. [Products Analysis](#products)
# 3. [Sellers Analysis](#sellers)
# 4. [Orders Analysis](#o)

# %% [markdown]
# ## Table of Contents
#
# 1. [Customer Analysis](#customers)
#     - [What are the number of our registered customers?](#customers1)
#     - [Which state has the highest number of registered customers?](#customers2)
#     - [What are the top 5 cities based on registered customers?](#customers3)
#     - [What are the 5 states with the least number of registered customers?](#customers4)
#     - [Who are our top 100 customers based on total sales?](#customers5)
#     - [What are the IDs of customers that didn't make any orders since registration?](#customers6)
#
# 2. [Products Analysis](#products)
#     - [How many product categories do we have?](#products1)
#     - [How many products does each category have?](#products2)
#     - [What are the top 20 products contributing to sales?](#products3)
#     - [What are the top 20 product categories contributing to sales?](#products4)
#
# 3. [Sellers Analysis](#sellers)
#     - [How many sellers are registered with OList?](#sellers1)
#     - [How our sellers are geographically distributed?](#sellers2)
#     - [Who are our top 50 sellers based on total sales?](#sellers3)
#     - [Who are our worst performing sellers based on total sales?](#sellers4)
#
# 4. [Orders Analysis](#orders)
#     - [What is the period of time that is covered in the data?](#orders1)
#     - [How many delayed orders, what is their percentage?](#orders2)
#     - [How much is the average order value (AOV)?](#orders3)
#     - [What is the average freight cost?](#orders4)
#     - [What is the distribution of payment types?](#orders5)

# %% [markdown]
# <img src = 'pic_of_new_schema.jpg'> </img>

# %% [markdown]
# SETTING THE ATMOSPHERE

# %% [markdown]
# **<span style="font-size: 50px; color: purple;">1-Customers Analysis</span>**<a id="customers"></a>

# %% [markdown]
# <b>1- What are the number of our registered customers?</b><a id="customers1"></a>

# %%
# %%sql
# SELECT
#   COUNT(DISTINCT customer_unique_id) AS unique_customers
# FROM
#   customers
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(96096,)]

# %% [markdown]
# <b> 2- Which state has the highest number of registered customers? </b><a id="customers2"></a>

# %%
# %%sql
# SELECT
#   customer_state AS State,
#   COUNT(DISTINCT customer_unique_id) Cust_num
# FROM
#   customers
# GROUP BY
#   1
# ORDER BY
#   2 DESC
# LIMIT
#   1
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [('SP', 40302)]

# %% [markdown]
# <b> 3- What are the top 5 cities based on registered customers? </b><a id="customers3"></a>

# %%
# %%sql
# SELECT
#   customer_city AS City,
#   COUNT(DISTINCT customer_unique_id) Cust_num
# FROM
#   customers
# GROUP BY
#   1
# ORDER BY
#   2 DESC
# LIMIT
#   5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('sao paulo', 14984),
#  ('rio de janeiro', 6620),
#  ('belo horizonte', 2672),
#  ('brasilia', 2069),
#  ('curitiba', 1465)]

# %% [markdown]
# <b>4- What are the 5 states with the least number of registered customers?</b><a id="customers4"></a>

# %%
# %%sql
# SELECT
#   customer_state AS City,
#   COUNT(DISTINCT customer_unique_id) Cust_num
# FROM
#   customers
# GROUP BY
#   1
# ORDER BY
#   2
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('RR', 45), ('AP', 67), ('AC', 77), ('AM', 143), ('RO', 240)]

# %% [markdown]
# <b> 5- Who are our top 100 customers based on total sales? </b><a id="customers5"></a>

# %%
# %%sql
# SELECT
#   c.customer_Unique_id,
#   SUM(price + freight_value) AS total_sales
# FROM
#   customers c
#   LEFT JOIN orders o ON c.customer_id = o.customer_id
#   LEFT JOIN order_items oi ON o.order_id = oi.order_id
# GROUP BY
#   1
# ORDER BY
#   total_sales desc
# LIMIT
#   100;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 100 rows affected.
# [('da122df9eeddfedc1dc1f5349a1a690c', Decimal('7571.63')),
#  ('dc4802a71eae9be1dd28f5d788ceb526', Decimal('6929.31')),
#  ('459bef486812aa25204be022145caa62', Decimal('6922.21')),
#  ('ff4159b92c40ebe40454e3e6a7c35ed6', Decimal('6726.66')),
#  ('eebb5dda148d3893cdaf5b5ca3040ccb', Decimal('4764.34')),
#  ('48e1ac109decbb87765a3eade6854098', Decimal('4681.78')),
#  ('edde2314c6c30e864a128ac95d6b2112', Decimal('4513.32')),
#  ('a229eba70ec1c2abef51f04987deb7a5', Decimal('4445.50')),
#  ('edf81e1f3070b9dac83ec83dacdbb9bc', Decimal('4194.76')),
#  ('fa562ef24d41361e476e748681810e1e', Decimal('4175.26')),
#  ('ca27f3dac28fb1063faddd424c9d95fa', Decimal('4163.51')),
#  ('055ec572ac7f3c7bdd04a183830ebe59', Decimal('4053.08')),
#  ('5e713be0853d8986528d7869a0811d2b', Decimal('4042.74')),
#  ('58483a1c055dfb600f57c5b867174542', Decimal('4034.44')),
#  ('011875f0176909c5cf0b14a9138bb691', Decimal('4016.91')),
#  ('f0767ae738c3d90e7b737d7b8b8bb4d1', Decimal('3979.55')),
#  ('bc5e25094a7d51b6aee35236572e64f4', Decimal('3826.80')),
#  ('3fec1a05177762f279472253113d568a', Decimal('3792.59')),
#  ('5d09b0d82126457e2a8ebfb9c9a1ffc4', Decimal('3736.22')),
#  ('03796b63235e0e0a299084988c662c7e', Decimal('3602.47')),
#  ('59d66d72939bc9497e19d89c61a96d5f', Decimal('3559.99')),
#  ('2c3b08cf3584d8c0a81d9618a73aa219', Decimal('3526.46')),
#  ('95a744604de66a2e40e18086e69be4f2', Decimal('3406.47')),
#  ('ce3fe361f9e68bf0a813baaae1334d01', Decimal('3351.35')),
#  ('7a96eb0a685f5c19b7dad29fc802aa64', Decimal('3297.40')),
#  ('bbeb907759ef5fc169099af3c88d535d', Decimal('3209.72')),
#  ('6f00d356a4be20527662aaf12116baab', Decimal('3184.55')),
#  ('46450c74a0d8c5ca9395da1daac6c120', Decimal('3184.34')),
#  ('53fb3435773a4690e56010b169ee2820', Decimal('3155.82')),
#  ('c6111f70f40b3420e387493c627c27fa', Decimal('3126.50')),
#  ('895617ab63a9ad8881d9470f7427cd25', Decimal('3126.50')),
#  ('f886a3f43af9ac928fbb4b56436c528c', Decimal('3076.13')),
#  ('58c1b085b54c03a1f1ab5f13d64c2b1c', Decimal('3064.72')),
#  ('1b76903617af13189607a36b0469f6f3', Decimal('3051.74')),
#  ('ff0ae98646e7bbb41cf0f0d3991fef98', Decimal('3048.27')),
#  ('0f75637a7e2f7b6ae43665d1f7d0ca5d', Decimal('3044.12')),
#  ('2ae8173a688e326821403a5b7a6858c2', Decimal('3042.36')),
#  ('6172bd5b7f52ade8c6c4548b448ff54f', Decimal('3041.73')),
#  ('ea984b06b18cc6905bc2f9b0a3d1c986', Decimal('3024.08')),
#  ('ee2bb06c1d3f368e92084edefb7e4b57', Decimal('3016.01')),
#  ('ae04948ad7210ea76801b331080e0b3a', Decimal('3009.53')),
#  ('4683ad127301c1bcbd601a30bb22d2ba', Decimal('3005.06')),
#  ('129bfc164612d70a040a844b887dfec5', Decimal('2960.05')),
#  ('d9f8d6be11fb416742c9e35e725303f7', Decimal('2938.17')),
#  ('c38b132f1c68c14c0d3b32e66b796eba', Decimal('2838.22')),
#  ('8ad6fdb3d658f916f444aaf55a49bb29', Decimal('2828.42')),
#  ('c21e93b1d7b7a416d0f36fa6ebc1d60a', Decimal('2827.00')),
#  ('25bedfc6317ec4a379ef49b9c1049733', Decimal('2818.74')),
#  ('030a810edeec1ceea314282513023587', Decimal('2794.50')),
#  ('34ff67eb3466a779b2f6b6fd56a3b953', Decimal('2787.87')),
#  ('81d8bf17c9e450228efeedd2603edfaa', Decimal('2784.16')),
#  ('acc38a550c42d17125cd25c32a464d26', Decimal('2759.95')),
#  ('1e7097be947ad5d0f7819bdc9d8d7d0e', Decimal('2751.24')),
#  ('0de97ff655abfc142ba6fc83e86bf082', Decimal('2734.66')),
#  ('149b43a4776ea0a773ac75bc58830fb9', Decimal('2734.11')),
#  ('13d9920a16127351540bcd95ad4643c8', Decimal('2733.63')),
#  ('f140f377d666848e3712b51a2734d120', Decimal('2713.36')),
#  ('5e92460d739e8dd987e279285a1d278c', Decimal('2713.36')),
#  ('60b2ec19b8c18082cdb5180106a97cb5', Decimal('2692.82')),
#  ('c949c73b1318491d6b5b117acb3e24a4', Decimal('2681.29')),
#  ('bb149f7e7bfee3d984e265d0eae6181b', Decimal('2681.29')),
#  ('212b7cfb2631b23e85a4645a7cba1733', Decimal('2647.76')),
#  ('69e4e534ba5e6a8124d132b271923148', Decimal('2627.09')),
#  ('684da9ec00ee25877fe21ce197403d04', Decimal('2616.00')),
#  ('7814db11654d2bf3b43bae828b6eee05', Decimal('2606.01')),
#  ('7386ded430d6aeb715a0d087c38a2dfe', Decimal('2590.61')),
#  ('d8f1c3ed0de527caf0a7eceeb025b583', Decimal('2574.38')),
#  ('0621cda5f3ee9a2e6f3ae6ebb5fcdbe1', Decimal('2564.65')),
#  ('02ccceb879088a0253e1e46e0200bdb8', Decimal('2512.53')),
#  ('5dff3703f9d82688ab5a1c92df1e4b18', Decimal('2467.33')),
#  ('0bec90ebca9ff4b2b830950bb052e52d', Decimal('2457.44')),
#  ('8e07cbdbbb24328ece74135e2a81405b', Decimal('2455.12')),
#  ('d3ef55d6de8e4be1d4b905e8169224b5', Decimal('2452.12')),
#  ('d77aa95864ae5b42160937615628723a', Decimal('2450.10')),
#  ('85475e754525d6d222d917dbc8251801', Decimal('2438.51')),
#  ('24c0598e5978021ede868fbf7526544a', Decimal('2429.68')),
#  ('f755e02e22f99b9e1658cbd2186a212d', Decimal('2419.20')),
#  ('98133dfcdb0c24fa03c9eb4f0d69a6c4', Decimal('2416.00')),
#  ('f2a29b4d4c04184a9372bb7374d344ac', Decimal('2404.72')),
#  ('5d0a2980b292d049061542014e8960bf', Decimal('2404.72')),
#  ('5eed8cf8c54bff340300c214ddc32db4', Decimal('2404.72')),
#  ('87070b00f89fa49dd0b01ff4bf075b8c', Decimal('2389.78')),
#  ('e3e0e9112264452e4700d977ce02a4d1', Decimal('2384.50')),
#  ('c5a0eef09ffd9448532ef07854769930', Decimal('2360.42')),
#  ('7b0eaf68a16e4808e5388c67345033c9', Decimal('2340.08')),
#  ('c53a15252bb69a238a59b79c58a84bcf', Decimal('2338.48')),
#  ('6963ee67570e4454bf00b3e5fe52f734', Decimal('2337.40')),
#  ('c01158adcf91ee8f143d12388abe5f22', Decimal('2333.97')),
#  ('e6fad5b1c79a4760aac5068d09c46535', Decimal('2328.40')),
#  ('6a71207bf8784292ad3f6e107ab57755', Decimal('2325.22')),
#  ('8bce6306eb006a2ff6135ba36d33d644', Decimal('2324.99')),
#  ('c7794313e2cd53472b116a751350f132', Decimal('2323.25')),
#  ('8a8ac60fd8ea25925f379a33ef277987', Decimal('2322.32')),
#  ('352edc42ddf92161e32abb07872de623', Decimal('2315.83')),
#  ('bd90c3e19e58ff2439e72b0554026418', Decimal('2314.82')),
#  ('00c07da5ba0e07b4f248a3a373b07476', Decimal('2304.68')),
#  ('6ddbc64bd04d40f7768ff088d94cbeb8', Decimal('2299.66')),
#  ('ec4b05ce75316354ba9b297f64377ed6', Decimal('2288.31')),
#  ('7dd0031f1da839843abbcda4e9fb317b', Decimal('2267.18')),
#  ('a58b1fe8146940d706e5f07d73bc7d51', Decimal('2264.90'))]

# %% [markdown]
# <b> 6- What are the IDs of customers that didn't make any orders since registeration? </b><a id="customers6"></a>

# %%
# %%sql
# WITH inactive_cust AS (SELECT
#   c.customer_Unique_id AS unique_id,
#   SUM(price + freight_value) AS total_sales
# FROM
#   customers c
#   LEFT JOIN orders o ON c.customer_id = o.customer_id
#   LEFT JOIN order_items oi ON o.order_id = oi.order_id
# GROUP BY
#   1
# HAVING
#   total_sales IS NULL)
#
# SELECT
#         COUNT(unique_id) AS `Count`,
#         ROUND(COUNT(unique_id) * 1.00 /
#             (SELECT COUNT(DISTINCT customer_unique_id) FROM customers) * 100, 2) AS Percentage
# FROM inactive_cust;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(676, Decimal('0.70'))]

# %% [markdown]
# **<span style="font-size: 50px; color: purple;">2-Product Analysis</span>**<a id="products"></a>

# %% [markdown]
# <b>1- How many product categories do we have?</b><a id="products1"></a>

# %%
# %%sql
# SELECT
#   COUNT(DISTINCT product_category_name)
# FROM
#   products
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(73,)]

# %% [markdown]
# <b>2- How many products does each category have?</b><a id="products2"></a>

# %%
# %%sql
# WITH
#   portugese_names AS (
#     SELECT
#       product_category_name,
#       COUNT(product_category_name) AS products_per_category
#     FROM
#       products
#     GROUP BY
#       1
#   )
# SELECT
#   ct.product_category_name_english,
#   o.products_per_category
# FROM
#   portugese_names AS o
#   INNER JOIN category_translation AS ct ON o.product_category_name = ct.product_category_name
# ORDER BY
#   2 DESC
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 73 rows affected.
# [('bed_bath_table', 3029),
#  ('sports_leisure', 2867),
#  ('furniture_decor', 2657),
#  ('health_beauty', 2444),
#  ('housewares', 2335),
#  ('auto', 1900),
#  ('computers_accessories', 1639),
#  ('toys', 1411),
#  ('watches_gifts', 1329),
#  ('telephony', 1134),
#  ('baby', 919),
#  ('perfumery', 868),
#  ('fashion_bags_accessories', 849),
#  ('stationery', 849),
#  ('cool_stuff', 789),
#  ('garden_tools', 753),
#  ('pet_shop', 719),
#  ('electronics', 517),
#  ('construction_tools_construction', 400),
#  ('home_appliances', 370),
#  ('luggage_accessories', 349),
#  ('consoles_games', 317),
#  ('office_furniture', 309),
#  ('musical_instruments', 289),
#  ('small_appliances', 231),
#  ('home_construction', 225),
#  ('books_general_interest', 216),
#  ('fashion_shoes', 173),
#  ('furniture_living_room', 156),
#  ('air_conditioning', 124),
#  ('books_technical', 123),
#  ('fixed_telephony', 116),
#  ('home_confort', 111),
#  ('market_place', 104),
#  ('food_drink', 104),
#  ('fashion_male_clothing', 95),
#  ('kitchen_dining_laundry_garden_furniture', 94),
#  ('signaling_and_security', 93),
#  ('construction_tools_safety', 91),
#  ('home_appliances_2', 90),
#  ('costruction_tools_garden', 88),
#  ('food', 82),
#  ('drinks', 81),
#  ('construction_tools_lights', 78),
#  ('agro_industry_and_commerce', 74),
#  ('industry_commerce_and_business', 68),
#  ('christmas_supplies', 65),
#  ('audio', 58),
#  ('art', 55),
#  ('fashion_underwear_beach', 53),
#  ('dvds_blu_ray', 48),
#  ('furniture_bedroom', 45),
#  ('costruction_tools_tools', 39),
#  ('books_imported', 31),
#  ('small_appliances_home_oven_and_coffee', 31),
#  ('computers', 30),
#  ('cine_photo', 28),
#  ('fashio_female_clothing', 27),
#  ('music', 27),
#  ('party_supplies', 26),
#  ('arts_and_craftmanship', 19),
#  ('fashion_sport', 19),
#  ('flowers', 14),
#  ('diapers_and_hygiene', 12),
#  ('la_cuisine', 10),
#  ('furniture_mattress_and_upholstery', 10),
#  ('portable_kitchen_food_preparators', 10),
#  ('tablets_printing_image', 9),
#  ('home_comfort_2', 5),
#  ('fashion_childrens_clothes', 5),
#  ('pc_gamer', 3),
#  ('security_and_services', 2),
#  ('cds_dvds_musicals', 1)]

# %% [markdown]
# <b>3- What are the top 20 products contributing to sales?</b><a id="products3"></a>

# %%
# %%sql
# SELECT
#     product_id,
#     ROUND(Sum(price + freight_value)) AS Total_Sales
# from order_items
# GROUP BY 1
# order by 2 DESC
#     limit 20 ;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 20 rows affected.
# [('bb50f2e236e5eea0100680137654686c', Decimal('64839')),
#  ('d1c427060a0f73f6b889a5c7c61f2ac4', Decimal('57377')),
#  ('6cdd53843498f92890544667809f1595', Decimal('57148')),
#  ('d6160fb7873f184099d9bc95e30376af', Decimal('50326')),
#  ('99a4788cb24856965c36a24e339b6058', Decimal('48884')),
#  ('3dd2a17168ec895c781a9191c1e95ad7', Decimal('44927')),
#  ('5f504b3a1c75b73d6151be81eb05bdc9', Decimal('41726')),
#  ('25c38557cf793876c5abdd5931f922db', Decimal('40312')),
#  ('53b36df67ebb7c41585e8d54d6772e08', Decimal('37849')),
#  ('aca2eb7d00ea1a7b8ebd4e68314663af', Decimal('36708')),
#  ('e0d64dcfaa3b6db5c54ca298ae101d05', Decimal('35344')),
#  ('d285360f29ac7fd97640bf0baef03de0', Decimal('33356')),
#  ('7a10781637204d8d10485c71a6108a2e', Decimal('32616')),
#  ('f1c7f353075ce59d8a6f3cf58f419c9c', Decimal('32458')),
#  ('f819f0c84a64f02d3a5606ca95edd272', Decimal('30450')),
#  ('588531f8ec37e7d5ff5b7b22ea0488f8', Decimal('27623')),
#  ('5a848e4ab52fd5445cdc07aab1c40e48', Decimal('26866')),
#  ('16c4e87b98a9370a9cbc3a4658a3f45b', Decimal('26630')),
#  ('2b4609f8948be18874494203496bc318', Decimal('26560')),
#  ('52c80cedd4e90108bf4fa6a206ef6b03', Decimal('25129'))]

# %% [markdown]
# <b>4- What are the top 20 product categories contributing to sales?</b><a id="products4"></a>

# %%
# %%sql
# SELECT
#     product_category_name_english,
#     ROUND(Sum(price + freight_value)) AS Total_Sales
# from order_items oi join products p on oi.product_id = p.product_id
#                     join category_translation ct on p.product_category_name = ct.product_category_name
# GROUP BY 1
# order by 2 desc
# LIMIT 20 ;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 20 rows affected.
# [('health_beauty', Decimal('1384784')),
#  ('watches_gifts', Decimal('1285041')),
#  ('bed_bath_table', Decimal('1151658')),
#  ('sports_leisure', Decimal('1084445')),
#  ('computers_accessories', Decimal('936675')),
#  ('furniture_decor', Decimal('778022')),
#  ('housewares', Decimal('702968')),
#  ('cool_stuff', Decimal('702769')),
#  ('auto', Decimal('651009')),
#  ('toys', Decimal('549896')),
#  ('garden_tools', Decimal('521845')),
#  ('baby', Decimal('470598')),
#  ('perfumery', Decimal('438380')),
#  ('telephony', Decimal('372235')),
#  ('office_furniture', Decimal('272127')),
#  ('stationery', Decimal('269777')),
#  ('pet_shop', Decimal('237793')),
#  ('computers', Decimal('215516')),
#  ('musical_instruments', Decimal('203928')),
#  ('small_appliances', Decimal('199678'))]

# %% [markdown]
# **<span style="font-size: 50px; color: purple;">3-Sellers Analysis</span>**<a id="sellers"></a>

# %% [markdown]
# <b>1- How many sellers are registered with OList?</b><a id="sellers1"></a>

# %%
# %%sql
# SELECT count(seller_id) from sellers;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(3095,)]

# %% [markdown]
# <b>2- How our sellers are geographically distributed?</b><a id="sellers2"></a>

# %%
# %%sql
# SELECT seller_state, seller_city, count(*)
# FROM sellers
# group by 1, 2
# order by 3 desc
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 635 rows affected.
# [('SP', 'sao paulo', 695),
#  ('PR', 'curitiba', 124),
#  ('RJ', 'rio de janeiro', 93),
#  ('MG', 'belo horizonte', 66),
#  ('SP', 'ribeirao preto', 52),
#  ('SP', 'guarulhos', 50),
#  ('SP', 'ibitinga', 49),
#  ('SP', 'santo andre', 45),
#  ('SP', 'campinas', 41),
#  ('PR', 'maringa', 40),
#  ('SP', 'sao jose do rio preto', 33),
#  ('SP', 'sao bernardo do campo', 32),
#  ('SP', 'sorocaba', 32),
#  ('SP', 'osasco', 32),
#  ('DF', 'brasilia', 28),
#  ('RS', 'porto alegre', 27),
#  ('PR', 'londrina', 25),
#  ('GO', 'goiania', 23),
#  ('SC', 'joinville', 22),
#  ('SP', 'franca', 20),
#  ('SC', 'blumenau', 20),
#  ('SP', 'sao caetano do sul', 20),
#  ('SP', 'sao jose dos campos', 18),
#  ('SC', 'florianopolis', 17),
#  ('SP', 'limeira', 17),
#  ('SP', 'santos', 16),
#  ('RS', 'caxias do sul', 16),
#  ('SP', 'mogi das cruzes', 15),
#  ('SP', 'marilia', 15),
#  ('PR', 'cascavel', 14),
#  ('SP', 'jundiai', 14),
#  ('SP', 'bauru', 14),
#  ('SP', 'maua', 13),
#  ('SP', 'barueri', 13),
#  ('SP', 'sao carlos', 13),
#  ('MG', 'contagem', 12),
#  ('MG', 'uberlandia', 12),
#  ('SP', 'presidente prudente', 12),
#  ('SP', 'rio claro', 12),
#  ('SP', 'piracicaba', 12),
#  ('SP', 'atibaia', 11),
#  ('SP', 'araraquara', 11),
#  ('SP', 'catanduva', 10),
#  ('SP', 'americana', 10),
#  ('SP', 'taboao da serra', 10),
#  ('SP', 'praia grande', 10),
#  ('PR', 'arapongas', 10),
#  ('SP', 'birigui', 10),
#  ('SP', 'cotia', 10),
#  ('SC', 'brusque', 10),
#  ('SP', 'carapicuiba', 10),
#  ('RS', 'canoas', 9),
#  ('SC', 'jaragua do sul', 9),
#  ('SP', 'porto ferreira', 9),
#  ('SP', 'santana de parnaiba', 9),
#  ('SP', 'pedreira', 9),
#  ('SP', 'salto', 9),
#  ('SP', 'itaquaquecetuba', 9),
#  ('MG', 'juiz de fora', 9),
#  ('PR', 'sao jose dos pinhais', 9),
#  ('SP', 'diadema', 9),
#  ('SC', 'itajai', 8),
#  ('SP', 'assis', 8),
#  ('PR', 'colombo', 8),
#  ('SP', 'mogi guacu', 8),
#  ('RJ', 'niteroi', 8),
#  ('PR', 'apucarana', 8),
#  ('MG', 'divinopolis', 8),
#  ('PR', 'toledo', 8),
#  ('SP', 'indaiatuba', 8),
#  ('RJ', 'sao goncalo', 7),
#  ('SP', 'sao roque', 7),
#  ('SP', 'valinhos', 7),
#  ('CE', 'fortaleza', 7),
#  ('BA', 'salvador', 7),
#  ('SP', 'jacarei', 7),
#  ('PR', 'pinhais', 7),
#  ('SC', 'palhoca', 7),
#  ('SP', 'ribeirao pires', 6),
#  ('SP', 'taubate', 6),
#  ('MG', 'uba', 6),
#  ('PR', 'ponta grossa', 6),
#  ('SP', 'lencois paulista', 6),
#  ('MG', 'santa rita do sapucai', 6),
#  ('PR', 'fazenda rio grande', 6),
#  ('SP', 'guaruja', 6),
#  ('MG', 'claudio', 6),
#  ('RS', 'novo hamburgo', 6),
#  ('RJ', 'petropolis', 6),
#  ('RS', 'lajeado', 5),
#  ('PR', 'foz do iguacu', 5),
#  ('MG', 'betim', 5),
#  ('RJ', 'nova friburgo', 5),
#  ('SP', 'penapolis', 5),
#  ('RJ', 'nova iguacu', 5),
#  ('PE', 'recife', 5),
#  ('SC', 'tubarao', 5),
#  ('SC', 'sao jose', 5),
#  ('MG', 'pocos de caldas', 5),
#  ('SP', 'braganca paulista', 5),
#  ('SP', 'amparo', 5),
#  ('SP', 'sumare', 5),
#  ('PR', 'francisco beltrao', 4),
#  ('SP', 'botucatu', 4),
#  ('SC', 'criciuma', 4),
#  ('SP', 'itapevi', 4),
#  ('SP', 'sp', 4),
#  ('MG', 'sete lagoas', 4),
#  ('SP', "santa barbara d'oeste", 4),
#  ('SP', 'garca', 4),
#  ('SC', 'rio do sul', 4),
#  ('SP', 'jaguariuna', 4),
#  ('SP', 'itatiba', 4),
#  ('SP', 'tupa', 4),
#  ('MG', 'borda da mata', 4),
#  ('SP', 'itu', 4),
#  ('SP', 'votorantim', 4),
#  ('SP', 'capivari', 4),
#  ('SP', 'jaci', 4),
#  ('MG', 'formiga', 4),
#  ('ES', 'cachoeiro de itapemirim', 4),
#  ('ES', 'vila velha', 4),
#  ('SP', 'barretos', 4),
#  ('SP', 'itapecerica da serra', 4),
#  ('ES', 'vitoria', 4),
#  ('MG', 'varginha', 4),
#  ('SP', 'votuporanga', 4),
#  ('SP', 'paulinia', 4),
#  ('SP', 'jau', 4),
#  ('RJ', 'barra mansa', 4),
#  ('SP', 'fernandopolis', 4),
#  ('MS', 'campo grande', 4),
#  ('PR', 'umuarama', 4),
#  ('MG', 'araguari', 4),
#  ('SP', 'mirassol', 4),
#  ('SP', 'aracatuba', 4),
#  ('SP', 'pompeia', 3),
#  ('SC', 'sao bento do sul', 3),
#  ('SP', 'sao paulo - sp', 3),
#  ('SP', 'ferraz de vasconcelos', 3),
#  ('SP', 'aruja', 3),
#  ('MG', 'tres coracoes', 3),
#  ('SP', 'batatais', 3),
#  ('RJ', 'sao joao de meriti', 3),
#  ('RS', 'bento goncalves', 3),
#  ('MG', 'conselheiro lafaiete', 3),
#  ('GO', 'anapolis', 3),
#  ('PR', 'sarandi', 3),
#  ('RS', 'venancio aires', 3),
#  ('SP', 'mogi mirim', 3),
#  ('SP', 'curitiba', 3),
#  ('RS', 'santa maria', 3),
#  ('SC', 'balneario camboriu', 3),
#  ('RJ', 'macae', 3),
#  ('SP', 'araras', 3),
#  ('SP', 'vargem grande do sul', 3),
#  ('MG', 'montes claros', 3),
#  ('SP', 'osvaldo cruz', 3),
#  ('SP', 'tatui', 3),
#  ('RS', 'carazinho', 3),
#  ('SP', 'tabatinga', 3),
#  ('SP', 'suzano', 3),
#  ('RS', 'cachoeirinha', 3),
#  ('ES', 'serra', 3),
#  ('GO', 'morrinhos', 3),
#  ('SC', 'navegantes', 3),
#  ('PR', 'santa terezinha de itaipu', 3),
#  ('PR', 'guaratuba', 3),
#  ('PR', 'rolandia', 3),
#  ('SP', 'serra negra', 3),
#  ('PR', 'cambe', 3),
#  ('RJ', 'mesquita', 3),
#  ('SP', 'laranjal paulista', 3),
#  ('PR', 'loanda', 3),
#  ('SP', 'boituva', 3),
#  ('PR', 'campo largo', 3),
#  ('RJ', 'duque de caxias', 3),
#  ('SP', 'artur nogueira', 3),
#  ('MG', 'uberaba', 3),
#  ('RS', 'pelotas', 3),
#  ('ES', 'cariacica', 2),
#  ('GO', 'uruacu', 2),
#  ('MG', 'ribeirao das neves', 2),
#  ('RN', 'natal', 2),
#  ('SP', 'cosmopolis', 2),
#  ('SC', 'rodeio', 2),
#  ('SP', 'itajobi', 2),
#  ('MG', 'alfenas', 2),
#  ('PB', 'joao pessoa', 2),
#  ('SP', 'itajai', 2),
#  ('RS', 'montenegro', 2),
#  ('PR', 'pitanga', 2),
#  ('BA', 'lauro de freitas', 2),
#  ('SC', 'imbituba', 2),
#  ('SP', 'bariri', 2),
#  ('MG', 'jacutinga', 2),
#  ('SP', 'pradopolis', 2),
#  ('PR', 'itaipulandia', 2),
#  ('SC', 'gaspar', 2),
#  ('SC', 'sao ludgero', 2),
#  ('SC', 'jaguaruna', 2),
#  ('SC', 'indaial', 2),
#  ('MG', 'vicosa', 2),
#  ('SP', 'registro', 2),
#  ('SP', 'cafelandia', 2),
#  ('SP', 'dois corregos', 2),
#  ('SP', 'sao pedro', 2),
#  ('MG', 'itauna', 2),
#  ('SP', 'igaracu do tiete', 2),
#  ('SP', 'santa barbara d´oeste', 2),
#  ('SP', 'belo horizonte', 2),
#  ('SC', 'lages', 2),
#  ('RS', 'campo bom', 2),
#  ('RS', 'sao leopoldo', 2),
#  ('SC', 'sombrio', 2),
#  ('SC', 'porto belo', 2),
#  ('SP', 'campo limpo paulista', 2),
#  ('MG', 'araxa', 2),
#  ('MG', 'coronel fabriciano', 2),
#  ('SP', 'sao jose do rio pardo', 2),
#  ('RS', 'santa rosa', 2),
#  ('MG', 'dores de campos', 2),
#  ('MG', 'lagoa da prata', 2),
#  ('SC', 'canoinhas', 2),
#  ('SP', 'embu das artes', 2),
#  ('SP', 'jaboticabal', 2),
#  ('SP', 'conchal', 2),
#  ('SP', 'echapora', 2),
#  ('SP', 'itapetininga', 2),
#  ('MG', 'sao joao del rei', 2),
#  ('SC', 'treze tilias', 2),
#  ('RJ', 'nilopolis', 2),
#  ('MG', 'patos de minas', 2),
#  ('SC', 'chapeco', 2),
#  ('RS', 'farroupilha', 2),
#  ('SP', 'franco da rocha', 2),
#  ('RS', 'estancia velha', 2),
#  ('MG', 'ipatinga', 2),
#  ('PR', 'araucaria', 2),
#  ('SC', 'timbo', 2),
#  ('PR', 'castro', 2),
#  ('RS', 'flores da cunha', 2),
#  ('PE', 'caruaru', 2),
#  ('SC', 'videira', 2),
#  ('SP', 'caxias do sul', 2),
#  ('SP', 'tanabi', 2),
#  ('SC', 'garopaba', 2),
#  ('RS', 'viamao', 2),
#  ('SC', 'paulo lopes', 2),
#  ('MG', 'tiradentes', 2),
#  ('SP', 'mairipora', 2),
#  ('SP', 'lorena', 2),
#  ('MT', 'cuiaba', 2),
#  ('RJ', 'belford roxo', 2),
#  ('SC', 'xanxere', 2),
#  ('RJ', 'armacao dos buzios', 2),
#  ('SP', 'hortolandia', 2),
#  ('SC', 'curitibanos', 2),
#  ('SP', 'cajamar', 2),
#  ('SC', 'laurentino', 2),
#  ('SP', 'rio de janeiro', 2),
#  ('SP', 'bady bassitt', 2),
#  ('SP', 'nova odessa', 2),
#  ('MG', 'baependi', 2),
#  ('PR', 'pato branco', 2),
#  ('GO', 'formosa', 2),
#  ('RJ', 'teresopolis', 2),
#  ('MG', 'timoteo', 1),
#  ('SP', 'ribeirao preto / sao paulo', 1),
#  ('SC', 'bombinhas', 1),
#  ('RS', 'ivoti', 1),
#  ('RJ', 'santo antonio de padua', 1),
#  ('RJ', 'queimados', 1),
#  ('RS', 'santo angelo', 1),
#  ('PR', 'paincandu', 1),
#  ('MA', 'sao luis', 1),
#  ('RJ', 'saquarema', 1),
#  ('MG', 'vespasiano', 1),
#  ('SP', 'cananeia', 1),
#  ('SP', 'louveira', 1),
#  ('PR', 'teixeira soares', 1),
#  ('SP', 'francisco morato', 1),
#  ('SP', 'pedrinhas paulista', 1),
#  ('SP', 'ourinhos', 1),
#  ('SP', 'pederneiras', 1),
#  ('SP', 'aparecida', 1),
#  ('SC', "sao miguel d'oeste", 1),
#  ('RJ', 'angra dos reis', 1),
#  ('SP', 'laranjeiras do sul', 1),
#  ('RS', 'ipe', 1),
#  ('SC', 'garuva', 1),
#  ('MG', 'monte siao', 1),
#  ('ES', 'muqui', 1),
#  ('MG', 'ouro preto', 1),
#  ('PR', 'guaira', 1),
#  ('MG', 'minas gerais', 1),
#  ('SP', 'sao vicente', 1),
#  ('SP', 'riberao preto', 1),
#  ('SC', 'rio negrinho', 1),
#  ('SP', 'varzea paulista', 1),
#  ('MG', 'ouro fino', 1),
#  ('SC', 'araquari', 1),
#  ('PR', 'bocaiuva do sul', 1),
#  ('MG', 'cataguases', 1),
#  ('SP', 'sp / sp', 1),
#  ('MG', 'lambari', 1),
#  ('SP', 'barrinha', 1),
#  ('MT', 'jaciara', 1),
#  ('RJ', 'paraiba do sul', 1),
#  ('SC', 'santa cecilia', 1),
#  ('SP', 'guaira', 1),
#  ('PR', 'guarapuava', 1),
#  ('SP', 'laguna', 1),
#  ('PR', 'andira-pr', 1),
#  ('PR', 'bandeirantes', 1),
#  ('MG', 'itau de minas', 1),
#  ('SP', 'robeirao preto', 1),
#  ('PB', 'serra redonda', 1),
#  ('PR', 'cianorte', 1),
#  ('SP', 'poa', 1),
#  ('SP', 'pedregulho', 1),
#  ('SP', 'itaporanga', 1),
#  ('SP', 'sao jose do rio pret', 1),
#  ('CE', 'varzea alegre', 1),
#  ('BA', 'irece', 1),
#  ('SP', 'buritama', 1),
#  ('MG', 'castro pires', 1),
#  ('MG', 'sabara', 1),
#  ('SC', 'sao francisco do sul', 1),
#  ('MT', 'sinop', 1),
#  ('ES', 'afonso claudio', 1),
#  ('RJ', 'volta redonda', 1),
#  ('SP', 'auriflama', 1),
#  ('SP', 'scao jose do rio pardo', 1),
#  ('RS', 'parai', 1),
#  ('AM', 'manaus', 1),
#  ('RS', 'uruguaiana', 1),
#  ('MG', 'carmo do cajuru', 1),
#  ('RO', 'porto velho', 1),
#  ('RS', 'condor', 1),
#  ('PR', 'cascavael', 1),
#  ('MG', 'congonhas', 1),
#  ('SP', 'dracena', 1),
#  ('PR', 'ampere', 1),
#  ('CE', 'mucambo', 1),
#  ('SP', 'cerqueira cesar', 1),
#  ('RN', 'rio de janeiro', 1),
#  ('RS', 'rolante', 1),
#  ('PR', 'uniao da vitoria', 1),
#  ('SP', 'aguas claras df', 1),
#  ('PR', 'mandirituba', 1),
#  ('DF', 'gama', 1),
#  ('SC', 'nova trento', 1),
#  ('SP', 'sertanopolis', 1),
#  ('MG', 'ponte nova', 1),
#  ('MG', 'pouso alegre', 1),
#  ('SP', 'jales', 1),
#  ('MG', 'barbacena', 1),
#  ('PR', 'terra boa', 1),
#  ('SP', 'holambra', 1),
#  ('MG', 'governador valadares', 1),
#  ('MG', 'guanhaes', 1),
#  ('SP', 'caieiras', 1),
#  ('DF', 'brasilia df', 1),
#  ('RS', 'imigrante', 1),
#  ('ES', 'domingos martins', 1),
#  ('BA', 'bahia', 1),
#  ('SP', 'pinhalzinho', 1),
#  ('BA', 'barro alto', 1),
#  ('RJ', 'resende', 1),
#  ('SC', 'luiz alves', 1),
#  ('SP', 'cordeiropolis', 1),
#  ('PR', 'japira', 1),
#  ('MG', 'pedro leopoldo', 1),
#  ('PI', 'teresina', 1),
#  ('SP', 'volta redonda', 1),
#  ('SC', 'taio', 1),
#  ('SP', 'guariba', 1),
#  ('MG', 'oliveira', 1),
#  ('PR', 'irati', 1),
#  ('BA', "arraial d'ajuda (porto seguro)", 1),
#  ('SE', 'aracaju', 1),
#  ('PR', 'vendas@creditparts.com.br', 1),
#  ('RS', 'bage', 1),
#  ('AC', 'rio branco', 1),
#  ('PR', 'entre rios do oeste', 1),
#  ('PR', 'cornelio procopio', 1),
#  ('SP', 'itapui', 1),
#  ('SP', 'portoferreira', 1),
#  ('RS', 'ronda alta', 1),
#  ('BA', 'feira de santana', 1),
#  ('SC', 'rio do oeste', 1),
#  ('RS', 'rio grande', 1),
#  ('RN', 'parnamirim', 1),
#  ('SP', 'monte alegre do sul', 1),
#  ('PR', 'california', 1),
#  ('RS', 'triunfo', 1),
#  ('SP', 'sao pauo', 1),
#  ('SP', 'chapeco', 1),
#  ('RS', 'nova petropolis', 1),
#  ('SP', 'bertioga', 1),
#  ('SP', 'mogi das cruses', 1),
#  ('SP', 'monteiro lobato', 1),
#  ('PR', 'paranavai', 1),
#  ('MG', 'joao pinheiro', 1),
#  ('MG', 'campo do meio', 1),
#  ('SC', 'balenario camboriu', 1),
#  ('ES', 'viana', 1),
#  ('PR', 'pinhais/pr', 1),
#  ('SP', 'fernando prestes', 1),
#  ('MG', 'divisa nova', 1),
#  ('RJ', 'itaborai', 1),
#  ('SP', 'presidente bernardes', 1),
#  ('BA', 'ipira', 1),
#  ('RS', 'alvorada', 1),
#  ('BA', 'eunapolis', 1),
#  ('SP', 'ribeirao pretp', 1),
#  ('SP', 'macatuba', 1),
#  ('RS', 'campina das missoes', 1),
#  ('PA', 'marechal candido rondon', 1),
#  ('RJ', 'rio bonito', 1),
#  ('SP', 'sao sebastiao da grama/sp', 1),
#  ('SP', 'bebedouro', 1),
#  ('PR', 'marialva', 1),
#  ('GO', 'piracanjuba', 1),
#  ('RS', 'torres', 1),
#  ('SP', 'brotas', 1),
#  ('SP', 'sao joaquim da barra', 1),
#  ('SP', 'marapoama', 1),
#  ('SP', 'sao paulop', 1),
#  ('PR', 'pinhalao', 1),
#  ('SP', 's jose do rio preto', 1),
#  ('SP', 'monte alto', 1),
#  ('SP', 'sao paulo / sao paulo', 1),
#  ('SP', 'alambari', 1),
#  ('SP', 'mogi das cruzes / sp', 1),
#  ('PR', 'marechal candido rondon', 1),
#  ('RS', 'novo hamburgo, rio grande do sul, brasil', 1),
#  ('SP', 'rio das pedras', 1),
#  ('SP', 'mineiros do tiete', 1),
#  ('SC', 'lages - sc', 1),
#  ('MG', 'lagoa santa', 1),
#  ('PB', 'campina grande', 1),
#  ('PE', 'vitoria de santo antao', 1),
#  ('SC', 'xaxim', 1),
#  ('RJ', 'campos dos goytacazes', 1),
#  ('RS', 'santa cruz do sul', 1),
#  ('ES', 'cariacica / es', 1),
#  ('SP', 'rio bonito', 1),
#  ('SP', 'tambau', 1),
#  ('SC', 'picarras', 1),
#  ('SC', 'barra velha', 1),
#  ('SP', 'jacarei / sao paulo', 1),
#  ('SP', 'blumenau', 1),
#  ('SP', 'tiete', 1),
#  ('SP', 'tabao da serra', 1),
#  ('RJ', 'tres rios', 1),
#  ('SP', 'vila velha', 1),
#  ('RJ', 'mage', 1),
#  ('MG', 'congonhal', 1),
#  ('SC', 'itapema', 1),
#  ('PR', 'medianeira', 1),
#  ('SP', 'guaimbe', 1),
#  ('SP', 'nhandeara', 1),
#  ('SP', 'bom jesus dos perdoes', 1),
#  ('MG', 'belo horizont', 1),
#  ('SP', 'ipua', 1),
#  ('SC', 'braco do norte', 1),
#  ('SP', 'maua/sao paulo', 1),
#  ('RJ', 'vassouras', 1),
#  ('PR', 'sao  jose dos pinhais', 1),
#  ('SP', 'goioere', 1),
#  ('RS', 'tres de maio', 1),
#  ('RS', 'horizontina', 1),
#  ('MG', 'andradas', 1),
#  ('CE', 'caucaia', 1),
#  ('SC', 'cacador', 1),
#  ('SP', 'pirituba', 1),
#  ('SP', 'porto alegre', 1),
#  ('SP', 'clementina', 1),
#  ('MG', 'joao monlevade', 1),
#  ('PR', 'palotina', 1),
#  ('MG', 'ibia', 1),
#  ('RS', 'erechim', 1),
#  ('RJ', 'bom jardim', 1),
#  ('SP', 'cravinhos', 1),
#  ('GO', 'rio verde', 1),
#  ('SP', 'ao bernardo do campo', 1),
#  ('GO', 'luziania', 1),
#  ('MG', 'muriae', 1),
#  ('GO', 'jaragua', 1),
#  ('MG', 'janauba', 1),
#  ('SP', 'vicente de carvalho', 1),
#  ('MS', 'coxim', 1),
#  ('MG', 'carmo da mata', 1),
#  ('MG', 'camanducaia', 1),
#  ('SP', 'leme', 1),
#  ('SP', 'florianopolis', 1),
#  ('GO', 'aparecida de goiania', 1),
#  ('SP', 'mirandopolis', 1),
#  ('SP', 'bofete', 1),
#  ('RS', 'sapiranga', 1),
#  ('MG', 'ilicinea', 1),
#  ('SP', 'pinhais', 1),
#  ('SP', 'carapicuiba / sao paulo', 1),
#  ('SP', 'miguelopolis', 1),
#  ('SP', 'sao bernardo do capo', 1),
#  ('SP', 'orlandia', 1),
#  ('RO', 'ji parana', 1),
#  ('SP', 'socorro', 1),
#  ('PR', 'campo mourao', 1),
#  ('SP', 'jarinu', 1),
#  ('PB', 'mamanguape', 1),
#  ('PR', 'mandaguari', 1),
#  ('SP', 'itirapina', 1),
#  ('MG', 'prados', 1),
#  ('PR', 'sao jose dos pinhas', 1),
#  ('PR', 'colorado', 1),
#  ('RS', 'paraiso do sul', 1),
#  ('SP', 'santa rosa de viterbo', 1),
#  ('MG', 'fronteira', 1),
#  ('GO', 'santa terezinha de goias', 1),
#  ('MG', 'mateus leme', 1),
#  ('SP', 'descalvado', 1),
#  ('ES', 'colatina', 1),
#  ('SP', 'ipira', 1),
#  ('MG', 'extrema', 1),
#  ('SP', 'garulhos', 1),
#  ('RS', 'santo antonio da patrulha', 1),
#  ('MG', 'passos', 1),
#  ('PR', 'parana', 1),
#  ('PR', 'formosa do oeste', 1),
#  ('SC', 'santa catarina', 1),
#  ('SC', 'floranopolis', 1),
#  ('SP', 'sao joao da boa vista', 1),
#  ('SP', 'santa maria da serra', 1),
#  ('PR', 'imbituva', 1),
#  ('MG', 'ibirite', 1),
#  ('PR', 'campo magro', 1),
#  ('RJ', 'paracambi', 1),
#  ('SP', 'sao paulo sp', 1),
#  ('SP', 'mairinque', 1),
#  ('PR', 'almirante tamandare', 1),
#  ('SP', 'sao paluo', 1),
#  ('SP', 'guara', 1),
#  ('SP', 'auriflama/sp', 1),
#  ('SP', 'vera cruz', 1),
#  ('SE', 'neopolis', 1),
#  ('RS', 'portao', 1),
#  ('RS', 'imbe', 1),
#  ('BA', 'guanambi', 1),
#  ('SC', 'concordia', 1),
#  ('CE', 'pacatuba', 1),
#  ('SC', 'sao miguel do oeste', 1),
#  ('GO', 'abadia de goias', 1),
#  ('SP', 'pitangueiras', 1),
#  ('SP', 'tocantins', 1),
#  ('RJ', 'angra dos reis rj', 1),
#  ('SP', 'sando andre', 1),
#  ('SP', 'avare', 1),
#  ('SP', 'sbc/sp', 1),
#  ('PR', 'pato bragado', 1),
#  ('SP', 'palhoca', 1),
#  ('RJ', '04482255', 1),
#  ('SC', 'cordilheira alta', 1),
#  ('RJ', 'rio de janeiro \\rio de janeiro', 1),
#  ('CE', 'eusebio', 1),
#  ('BA', 'ilheus', 1),
#  ('PB', 'sao bento', 1),
#  ('MG', 'nova lima', 1),
#  ('RS', 'jacutinga', 1),
#  ('SC', 'massaranduba', 1),
#  ('BA', 'porto seguro', 1),
#  ('RJ', 'aperibe', 1),
#  ('SP', 'mococa', 1),
#  ('CE', 'juzeiro do norte', 1),
#  ('SP', 'guaratingueta', 1),
#  ('MG', 'centro', 1),
#  ('MG', 'guiricema', 1),
#  ('SP', 'londrina', 1),
#  ('RJ', 'rio de janeiro / rio de janeiro', 1),
#  ('PR', 'floresta', 1),
#  ('PR', 'mandaguacu', 1),
#  ('SP', 'mombuca', 1),
#  ('SP', 'olimpia', 1),
#  ('SP', 'juiz de fora', 1),
#  ('RS', 'igrejinha', 1),
#  ('SP', 'sbc', 1),
#  ('RJ', 'sao pedro da aldeia', 1),
#  ('SP', 'sao sebastiao', 1),
#  ('SP', 'itapeva', 1),
#  ('RS', 'cachoeira do sul', 1),
#  ('SC', 'campos novos', 1),
#  ('SP', 'vargem grande paulista', 1),
#  ('SP', 'cruzeiro', 1),
#  ('SC', 'camboriu', 1),
#  ('SP', 'ipaussu', 1),
#  ('SP', 'engenheiro coelho', 1),
#  ('PE', 'brejao', 1),
#  ('SP', 'presidente epitacio', 1),
#  ('SP', 'ubatuba', 1),
#  ('SP', 'ferraz de  vasconcelos', 1),
#  ('PR', 'jussara', 1),
#  ('SP', 'novo horizonte', 1),
#  ('SP', 'santa barbara d oeste', 1),
#  ('SP', 'sao  paulo', 1),
#  ('RN', 'messias targino', 1),
#  ('SP', 'embu guacu', 1),
#  ('SP', 'andradas', 1),
#  ('RS', 'arvorezinha', 1),
#  ('SP', 'pirassununga', 1),
#  ('SC', 'presidente getulio', 1),
#  ('SP', 'alvares machado', 1),
#  ('SC', 'pinhalzinho', 1),
#  ('RS', 'soledade', 1),
#  ('SP', 'santo andre/sao paulo', 1),
#  ('SP', 'taruma', 1),
#  ('SP', 'pilar do sul', 1),
#  ('SP', 'marechal candido rondon', 1),
#  ('SC', 'ararangua', 1),
#  ('MG', 'campanha', 1),
#  ('SP', 'santo antonio de posse', 1),
#  ('SC', 'orleans', 1),
#  ('RJ', 'rio de janeiro, rio de janeiro, brasil', 1),
#  ('SC', 'icara', 1),
#  ('SP', 'sao jose dos pinhais', 1),
#  ('RS', 'tres coroas', 1),
#  ('MG', 'bonfinopolis de minas', 1),
#  ('SP', 'serrana', 1),
#  ('MG', 'arinos', 1),
#  ('MG', 'caratinga', 1),
#  ('RJ', 'marica', 1),
#  ('MG', 'barbacena/ minas gerais', 1),
#  ('SP', 'jambeiro', 1),
#  ('MG', 'itabira', 1)]

# %% [markdown]
# <b>3- Who are our top 50 sellers based on total sales?</b><a id="sellers3"></a>

# %%
# %%sql
#
# SELECT
#      s.seller_id,
#     sum(price + freight_value) as total_sales
#
# FROM sellers s
#      inner join
#      order_items oi ON
#      s.seller_id = oi.seller_id
# group by 1
# order by 2 desc
# limit 50;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 50 rows affected.
# [('4869f7a5dfa277a7dca6462dcf3b52b2', Decimal('247344.85')),
#  ('4a3ca9315b744ce9f8e9374361493884', Decimal('224388.44')),
#  ('53243585a1d6dc2643021fd1853d8905', Decimal('219949.85')),
#  ('fa1c13f2614d7b5c4749cbc52fecda94', Decimal('204084.73')),
#  ('7e93a43ef30c4f03f38b393420bc753a', Decimal('182429.52')),
#  ('7c67e1448b00f6e969d365cea6b010ab', Decimal('182062.35')),
#  ('da8622b14eb17ae2831f4ac5b9dab84a', Decimal('170241.78')),
#  ('7a67c85e85bb2ce8582c35f2203ad736', Decimal('162213.67')),
#  ('6560211a19b47992c3666cc44a7e94c0', Decimal('148001.92')),
#  ('955fee9216a65b617aa5c0531780ce60', Decimal('139260.80')),
#  ('1025f0e2d44d7041d6cf58b6550e0bfa', Decimal('138779.55')),
#  ('46dc3b2cc0980fb8ec44634e21d2718e', Decimal('137855.30')),
#  ('cc419e0650a3c5ba77189a1882b7556a', Decimal('126741.97')),
#  ('a1043bafd471dff536d0c462352beb48', Decimal('126475.37')),
#  ('620c87c171fb2a6dd6e8bb4dec959fc6', Decimal('123899.95')),
#  ('5dceca129747e92ff8ef7a997dc4f8ca', Decimal('123210.96')),
#  ('7d13fca15225358621be4086e1eb0964', Decimal('121037.02')),
#  ('3d871de0142ce09b7081e2b9d1733cb1', Decimal('115244.79')),
#  ('1f50f920176fa81dab994f9023523100', Decimal('108704.62')),
#  ('edb1ef5e36e0c8cd84eb3c9b003e486d', Decimal('82719.99')),
#  ('ccc4bbb5f32a6ab2b7066a4130f114e3', Decimal('77315.47')),
#  ('cca3071e3e9bb7d12640c9fbe2301306', Decimal('73641.12')),
#  ('8581055ce74af1daba164fdbd55a40de', Decimal('73360.56')),
#  ('f7ba60f8c3f99e7ee4042fdef03b70c4', Decimal('69864.94')),
#  ('fe2032dab1a61af8794248c8196565c9', Decimal('68702.69')),
#  ('04308b1ee57b6625f47df1d56f00eedf', Decimal('63184.99')),
#  ('7ddcbb64b5bc1ef36ca8c151f6ec77df', Decimal('62673.94')),
#  ('17e34d8224d27a541263c4c64b11a56b', Decimal('60280.73')),
#  ('37be5a7c751166fbc5f8ccba4119e043', Decimal('59753.30')),
#  ('de722cd6dad950a92b7d4f82673f8833', Decimal('59172.54')),
#  ('f8db351d8c4c4c22c6835c19a46f01b0', Decimal('58986.22')),
#  ('218d46b86c1881d022bce9c68a7d4b15', Decimal('58850.38')),
#  ('522620dcb18a6b31cd7bdf73665113a9', Decimal('58638.43')),
#  ('ceaec5548eefc6e23e6607c5435102e7', Decimal('57596.79')),
#  ('b2ba3715d723d245138f291a6fe42594', Decimal('56155.58')),
#  ('f5a590cf36251cf1162ea35bef76fe84', Decimal('56138.01')),
#  ('17f51e7198701186712e53a39c564617', Decimal('54093.08')),
#  ('e882b2a25a10b9c057cc49695f222c19', Decimal('53856.82')),
#  ('ea8482cd71df3c1969d7b9473ff13abc', Decimal('53064.51')),
#  ('966cb4760537b1404caedd472cc610a5', Decimal('52935.87')),
#  ('8160255418d5aaa7dbdc9f4c64ebda44', Decimal('52913.92')),
#  ('2bf6a2c1e71bbd29a4ad64e6d3c3629f', Decimal('51629.49')),
#  ('d91fb3b7d041e83b64a00a3edfb37e4f', Decimal('50060.92')),
#  ('4e922959ae960d389249c378d1c939f5', Decimal('49872.37')),
#  ('77530e9772f57a62c906e1c21538ab82', Decimal('49606.80')),
#  ('c826c40d7b19f62a09e2d7c5e7295ee2', Decimal('49397.13')),
#  ('4d6d651bd7684af3fffabd5f08d12e5a', Decimal('49277.41')),
#  ('e9779976487b77c6d4ac45f75ec7afe9', Decimal('48301.52')),
#  ('850f4f8af5ea87287ac68de36e29107f', Decimal('48171.39')),
#  ('06a2c3af7b3aee5d69171b0e14f0ee87', Decimal('47757.80'))]

# %% [markdown]
# <b>4- Who are our worst performing sellers based on total sales?</b><a id="sellers4"></a>

# %%
# %%sql
#
# select
#     s.seller_id,
#     avg(review_score)
# from
#     sellers s inner join order_items oi on s.seller_id = oi.seller_id
#               inner join orders o on oi.order_id = o.order_id
#               inner join order_reviews ov on o.order_id = ov.order_id
# group by 1
# order by 2
# limit 50
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 50 rows affected.
# [('15ac3c501e2599e4917316fde5c5669a', Decimal('1.0000')),
#  ('2a50b7ee5aebecc6fd0ff9784a4747d6', Decimal('1.0000')),
#  ('001e6ad469a905060d959994f1b41e4f', Decimal('1.0000')),
#  ('37ceb404da208418c9032f0674e57804', Decimal('1.0000')),
#  ('3338e7a0710a195872be80e0d2423867', Decimal('1.0000')),
#  ('34aefe746cd81b7f3b23253ea28bef39', Decimal('1.0000')),
#  ('17adeba047385fb0c67d8e90b4296d21', Decimal('1.0000')),
#  ('43a5d4a57af536fddc96d08be3afdfcb', Decimal('1.0000')),
#  ('50c361bcf670d16f6df4d52de3dff924', Decimal('1.0000')),
#  ('1fddcb7b326905d3ad5efe82187db347', Decimal('1.0000')),
#  ('1444c08e64d55fb3c25f0f09c07ffcf2', Decimal('1.0000')),
#  ('20fd2d2080ed85fa67fad3fcbb2c1813', Decimal('1.0000')),
#  ('010da0602d7774602cd1b3f5fb7b709e', Decimal('1.0000')),
#  ('15aec03fe4cf30dfa574cf550f5ff5ff', Decimal('1.0000')),
#  ('1967a9e2ad6f51802b093147d861df58', Decimal('1.0000')),
#  ('5aaa890629f83706d8d9bfecd8377c1c', Decimal('1.0000')),
#  ('1b4b28463457a256e9a784ebe2a8f630', Decimal('1.0000')),
#  ('154bdf805377afea75a3bd158e9eab10', Decimal('1.0000')),
#  ('51a04a8a6bdcb23deccc82b0b80742cf', Decimal('1.0000')),
#  ('4003520d80d0bad1d5623f7aa3c63cda', Decimal('1.0000')),
#  ('5c603ffb38cbbf25a0e0698941324143', Decimal('1.0000')),
#  ('278b6e0b20c4f61fefaa0577943d7a35', Decimal('1.0000')),
#  ('4be2e7f96b4fd749d52dff41f80e39dd', Decimal('1.0000')),
#  ('40536e7ca18e1bce252828e5876466cc', Decimal('1.0000')),
#  ('391bbd13b6452244774beff1824006ed', Decimal('1.0000')),
#  ('553a440137d6e0cf776aee0bb83ac9f5', Decimal('1.0000')),
#  ('1f7dfad2cb384ea4d2d7e1ffbd78c407', Decimal('1.0000')),
#  ('0aa124728afc1131dff5655f4c6f487b', Decimal('1.0000')),
#  ('586a871d4f1221763fddb6ceefdeb95e', Decimal('1.0000')),
#  ('4e2627090e6e5b9fabba883a37897683', Decimal('1.0000')),
#  ('19484c79cef6c062cb177aa4ef2fcc3c', Decimal('1.0000')),
#  ('3da38366e7bd9baf6369071f782ecdf0', Decimal('1.0000')),
#  ('3a79f35a2344ede41af21267f61d5ec6', Decimal('1.0000')),
#  ('244b04680fdbded0acf5aebd9c92b44a', Decimal('1.0000')),
#  ('1e47d8b6546eb3a77b1acddcc9406242', Decimal('1.0000')),
#  ('58b98ccb79873e04eac4357cacc590d9', Decimal('1.0000')),
#  ('5dc4bdaf869e8c77c648078cbe8d59c2', Decimal('1.0000')),
#  ('3a52d63a8f9daf5a28f3626d7eb9bd28', Decimal('1.0000')),
#  ('5206cc4bc2297c833e6061c49bf9c43f', Decimal('1.0000')),
#  ('1fa2d3def6adfa70e58c276bb64fe5bb', Decimal('1.0000')),
#  ('5ca5d579b5857ee8709479b1047cecc3', Decimal('1.0000')),
#  ('1992f8fb6b19fcccd97ca819811e7267', Decimal('1.0000')),
#  ('4bc3d93e4a5f88a598d3d8ce4ae510b3', Decimal('1.0000')),
#  ('4e42581f08e8cfc7c090f930bac4552a', Decimal('1.0000')),
#  ('3bfad056cf05c00dabe2f895925d83b1', Decimal('1.0000')),
#  ('56a8b450e802502ba53a9885ee38e29f', Decimal('1.0000')),
#  ('15b3b1b81484422eb41df68ac87f1f50', Decimal('1.0000')),
#  ('324583d68897f5ddbaf38f6248322176', Decimal('1.0000')),
#  ('4f40d2ed38d1cc945364a7cd202a82c7', Decimal('1.0000')),
#  ('42d4b7e70819438f5ada61c965e92d7e', Decimal('1.0000'))]

# %% [markdown]
# **<span style="font-size: 50px; color: purple;">4-Orders Analysis</span>**<a id="orders"></a>

# %% [markdown]
# <b>1- What is the period of time that is covered in the data?<b/><a id="orders1"></a>

# %%
# %%sql
# SELECT MIN(order_purchase_timestamp) AS `Start`,
#        MAX(order_delivered_customer_date) AS `End`
# from orders;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [('2016-09-04 21:15:19', '2018-10-17 13:22:46')]

# %% [markdown]
# <b>2- How many delayed orders, what is their percentage?</b><a id="orders2"></a>

# %%
# %%sql
#
# SELECT count(*) AS `Count`,
#         Round(count(*) * 1.00 / (SELECT count(*) from orders) * 100, 2) AS delayed_orders_percentage
# FROM orders
# WHERE order_delivered_customer_date > order_estimated_delivery_date
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(7827, Decimal('7.87'))]

# %% [markdown]
# <b>3- How much is the average order value (AOV)?</b><a id="orders3"></a>

# %%
# %%sql
#
# with total_value As (
#     SELECT o.order_id,
#        sum(payment_value) as order_value
# from
#      orders o
#               inner join order_payments op on o.order_id = op.order_id
# group By 1
# limit 5)
#
# select round(avg(order_value)) AS avg_order_value
# from total_value
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(Decimal('159'),)]

# %% [markdown]
# <b>4- What is the average freight cost?</b><a id="orders4"></a>

# %%
# %%sql
#
# SELECT AVG(total_freight)
#
# FROM (SELECT order_id, SUM(freight_value) as total_freight from order_items group by order_id) as freight_per_order
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(Decimal('20.877352'),)]

# %% [markdown]
# <b>5- What is the distribution of payment types?</b><a id="orders5"></a>

# %%
# %%sql
#
# SELECT payment_type,
#         count(payment_type) as `count`,
#         ROUND(SUM(payment_value)) as total_sales
#
#
# FROM order_payments
# group by 1
# having total_sales
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 4 rows affected.
# [('credit_card', 76795, Decimal('12542084')),
#  ('boleto', 19784, Decimal('2869361')),
#  ('voucher', 5775, Decimal('379437')),
#  ('debit_card', 1529, Decimal('217990'))]
